# %%
from recipe_scrapers import scrape_me

# %%
scraper = scrape_me('https://www.allrecipes.com/recipe/158968/spinach-and-feta-turkey-burgers/')

# %%
scraper

# %%
scraper.title()
# Out:
# 'Spinach and Feta Turkey Burgers'

# %%
url = "https://mobile.kptncook.com/recipe/pinterest/Rote-Pasta-mit-Salbei-Zitronen-Butter-&-karamellisierten-Walnüssen/19e2eda2?_branch_match_id=927871221779919814&utm_source=SMS&utm_medium=sharing&_branch_referrer=H4sIAAAAAAAAA8soKSkottLXL85ILMrMS9fLLijJS87Pz9ZLzs%2FVN3b2SY4sTzatyk8CACm3OLEoAAAA"

# %%
19e2eda2 ?_branch_match_id=927871221779919814&utm_source=SMS&utm_medium=sharing&_branch_referrer=H4sIAAAAAAAAA8soKSkottLXL85ILMrMS9fLLijJS87Pz9ZLzs%2FVN3b2SY4sTzatyk8CACm3OL

# %%
import requests

from bs4 import BeautifulSoup

# %%
r = requests.get(url)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="KptnCook" property="og:site_name"/>
# <title>Red Pasta with Lemon-Sage Butter &amp; Caramelized Walnuts </title>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-M8XT3NQ');</script>
# <!-- End Google Tag Manager -->
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="app-id=795495986, app-clip-bundle-id=com.kptncook.KptnCook.Clip" name="apple-itunes-app"/>
# ...

# %%
from time import time

# %%
time()
# Out:
# 1647881568.621109

# %%
url = "https://mobile.kptncook.com/recipes/de/1647881568.621109?kptnkey=6q7QNKy-oIgk-IMuWisJ-jfN7s6"

# %%
r = requests.get(url)

# %%
receipts = r.json()

# %%
len(receipts)
# Out:
# 3

# %%
receipts[-1]
# Out:
# {'_id': {'$oid': '621f79994e0000fc037e4356'},
#  'localizedTitle': {'en': 'Vegan Broccoli & Hollandaise Pasta Bake',
#   'de': 'Veganer Käse-Nudel-Auflauf mit Brokkoli & Sauce Hollandaise',
#   'es': 'Pasta al horno con brócoli y salsa holandesa',
#   'fr': 'Gratin de pâtes au brocoli dans une sauce hollandaise',
#   'pt': 'Macarrão de forno com brócolis e molho holandês'},
#  'rtype': 'Vegan',
#  'authorComment': {'en': 'V-edgy pasta bake',
#   'de': 'Pastalover aufgepasst!',
#   'es': 'Una pasta verdurareramente deliciosa',
#   'fr': 'Le gratin végé-malin',
#   'pt': 'Veganamente delicioso!'},
#  'country': 'ww',
#  'preparationTime': 30,
#  'recipeNutrition': {'calories': 673,
#   'protein': 20,
#   'fat': 22,
#   'carbohydrate': 97},
#  'stepsEN': ['All set?',
#   'Cook pasta according to package instructions.',
#   'Meanwhile, wash broccoli and cut into florets.',
#   'Add broccoli florets to pasta <timer> before end of cooking time and simmer. Drain everything and set aside.',
# ...

# %%
kptnkey=6q7QNKy-oIgk-IMuWisJ-jfN7s6
